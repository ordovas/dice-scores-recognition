# %%
import cv2 
import os 
import random
# the "<" and ">" sig

# %%
tt = 5*["train"]+["test"]
def rotate_image(image, angle):
    image_center = tuple(np.array(image.shape[1::-1]) / 2)
    rot_mat = cv2.getRotationMatrix2D(image_center, angle, 1.0)
    result = cv2.warpAffine(image, rot_mat, image.shape[1::-1], flags=cv2.INTER_LINEAR)
    return result

# %%
random.shuffle(tt)

# %%
import numpy as np
np.random.uniform(0,360)
# Out:
# 79.57316569201315

# %%
files_dir="own_dataset/1d10/dataset_d10.txt"
with open(files_dir) as f:
    content = f.readlines()
videos = [x.strip() for x in content]

# %%
# Read the video from specified path 
def create_frames_old(file):
    print("own_dataset/d10/"+file)
    cam = cv2.VideoCapture("own_dataset/d6/"+file) 

    try: 

        # creating a folder named data 
        if not os.path.exists('data'): 
            os.makedirs('data') 

    # if not created then raise error 
    except OSError: 
        print ('Error: Creating directory of data') 

    # frame 
    currentframe = 0

    files=[]

    while(True): 

        # reading from frame 
        ret,frame = cam.read() 
        print(file)
        
        if ret: 
            # if video is still left continue creating images 
            name = "own_dataset/d6/"+ file[1:-4]+str(currentframe)+ '.jpg'
            print ('Creating...' + name) 
            files.append(name)
            # writing the extracted images 
            cv2.imwrite(name, frame) 

            # increasing counter so that it will 
            # show how many frames are created 
            currentframe += 1
        else: 
            break

    # Release all space and windows once done 
    cam.release() 
    cv2.destroyAllWindows() 
    return files

# %%
# Read the video from specified path 
def create_frames(file):
    print("own_dataset/1d10/"+file)
    cam = cv2.VideoCapture("own_dataset/1d10/"+file) 
    # 5 for the train and 1 for the test

    # Define the shape to save the different frames

    

    # frame 
    currentframe = 0

    files=[]

    while(True): 

        # reading from frame 
        ret,img0 = cam.read() 
        
        
        
        y=0
        h=1080
        x=500
        w=1000
        

        if ret: 
            # if video is still left continue creating images 


            name = "own_dataset/1d10/train/"+ file[1:-4]+"_"+str(currentframe)+ '.jpg'
                
                
            # writing the extracted images 
            if currentframe%6==0:
                if img0.shape[1] < img0.shape[0]:
                    img0=  cv2.rotate(img0, cv2.ROTATE_90_CLOCKWISE)
                name = "own_dataset/1d10/test/"+ file[1:-4]+"_"+str(currentframe)+'1.jpg'
                name = "own_dataset/1d10/test/"+ file[1:-4]+"_"+str(currentframe)+'2.jpg'
                files.append(name)
                img = img0[y:y+h, x:x+w]
                dd=img
                print ('Creating...' + name) 
                cv2.imwrite(name, img)
            else:
                if img0.shape[1] < img0.shape[0]:
                    img0=  cv2.rotate(img0, cv2.ROTATE_90_CLOCKWISE)
                name = "own_dataset/1d10/train/"+ file[1:-4]+"_"+str(currentframe)+'1.jpg'
                name = "own_dataset/1d10/train/"+ file[1:-4]+"_"+str(currentframe)+'2.jpg'
                img = img0[y:y+h, x:x+w]
                files.append(name)
                dd=img
                print ('Creating...' + name) 
                cv2.imwrite(name, img)
                

            # increasing counter so that it will 
            # show how many frames are created 
            currentframe += 1
        else: 
            break

    # Release all space and windows once done 
    cam.release() 
    cv2.destroyAllWindows() 
    return dd

# %%
frames=[]
for v in videos:
    temp=create_frames(v)
    for f in temp:
        frames.append(f)
# Out:
# own_dataset/1d10/v0/VID_20201213_110535.mp4
# Creating...own_dataset/1d10/test/0/VID_20201213_110535_02.jpg
# Creating...own_dataset/1d10/train/0/VID_20201213_110535_12.jpg
# Creating...own_dataset/1d10/train/0/VID_20201213_110535_22.jpg
# Creating...own_dataset/1d10/train/0/VID_20201213_110535_32.jpg
# Creating...own_dataset/1d10/train/0/VID_20201213_110535_42.jpg
# Creating...own_dataset/1d10/train/0/VID_20201213_110535_52.jpg
# Creating...own_dataset/1d10/test/0/VID_20201213_110535_62.jpg
# Creating...own_dataset/1d10/train/0/VID_20201213_110535_72.jpg
# Creating...own_dataset/1d10/train/0/VID_20201213_110535_82.jpg
# Creating...own_dataset/1d10/train/0/VID_20201213_110535_92.jpg
# Creating...own_dataset/1d10/train/0/VID_20201213_110535_102.jpg
# Creating...own_dataset/1d10/train/0/VID_20201213_110535_112.jpg
# Creating...own_dataset/1d10/test/0/VID_20201213_110535_122.jpg
# Creating...own_dataset/1d10/train/0/VID_20201213_110535_132.jpg
# ...

# %%
600*5/60
# Out:
# 50.0

# %%
aa = 5*["train"]+["test"]

# %%
aa

# %%
400/6

# %%
rr=lambda x: 5e-4 *0.99**x

# %%
rr(200)

# %%
rr(100)

# %%
rr(50)
