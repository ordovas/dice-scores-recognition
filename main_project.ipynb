# %% [markdown]
# # Dice Score Recognition project
#
# Here I show some examples of the code to show its performance

# %%
from detect_functions.score_pred_func import *
from detect_functions.dices_detect_func import *
from visualize_functions.image_functions import *

from visualize_functions.video_functions import *
from PIL import Image
import numpy as np

# %% [markdown]
# ### D6 dice
#
# In the `d6` list there are the name of some image files to be loaded. In the following cells the prediction of the dice throws are computed and ploted to see its performance.

# %%
d6=["IMG_20201214_225808.jpg",
"IMG_20201214_225854.jpg",
"IMG_20201214_225908.jpg",
"IMG_20201214_225914.jpg",
"IMG_20201214_225922.jpg",
"IMG_20201214_225925.jpg",
"IMG_20201214_225928.jpg",
"IMG_20201214_225932.jpg",
"IMG_20201214_225936.jpg",
"IMG_20201214_225939.jpg",
"IMG_20201214_225944.jpg",
"IMG_20201214_225952.jpg",
"IMG_20201214_225956.jpg",
"IMG_20201214_225959.jpg",
"IMG_20201214_231323.jpg",
"IMG_20201214_231328.jpg",
"IMG_20201214_231332.jpg",
"IMG_20201214_231337.jpg",
"IMG_20201214_231341.jpg",
"IMG_20201214_231344.jpg",
"IMG_20201214_231348.jpg",
"IMG_20201214_231354.jpg",
"IMG_20201214_231357.jpg",
"IMG_20201214_231401.jpg",
"IMG_20201214_231406.jpg"]

# %%
lnk="img_testing/d6/"+d6[10]
im = Image.open(lnk)
img_pru = np.asarray(im)

# %%
plot_detection(img_pru,detect_dices(img_pru)[1])

# %%
dd=segment_dices(img_pru,detect_dices(img_pru)[0])
plot_dices_d6(dd)
# Out:
# WARNING:tensorflow:From /home/ordovas/IRONHACK/dice-scores-recognition/detect_functions/score_pred_func.py:66: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %% [markdown]
# ### D10 dice
#
# Just as before, ln the `d10` list there are the name of some image files to be loaded and predicted.

# %%
d10=["IMG_20201215_001036.jpg",
"IMG_20201215_001045.jpg",
"IMG_20201215_001056.jpg",
"IMG_20201215_001101.jpg",
"IMG_20201215_001251.jpg",
"IMG_20201215_001254.jpg",
"IMG_20201216_170804.jpg",
"IMG_20201216_170806.jpg",
"IMG_20201216_170845.jpg",
"IMG_20201216_170856.jpg",
"IMG_20201216_170908.jpg",
"IMG_20201216_170920.jpg",
"IMG_20201216_170937.jpg",
"IMG_20201216_170950.jpg",
"IMG_20201216_170959.jpg",
"IMG_20201216_171012.jpg",
"IMG_20201216_171039.jpg",
"IMG_20201216_171042.jpg",
"IMG_20201216_171128.jpg"]

# %%
lnk="img_testing/d10/"+d10[1]
im = Image.open(lnk)
img_pru = np.asarray(im)
dd=segment_dices(img_pru,detect_dices(img_pru)[0])
plot_detection(img_pru,detect_dices(img_pru)[1])

# %%
plot_dices_d10(dd)

# %% [markdown]
# ### Webcam live detection of D6 dices
#
# Lastly, by executing the following function, we can check the score computations in real time.
#
# In order to shut down the webcam, just press the `Q` key.

# %%
webcam_dice_detector()
